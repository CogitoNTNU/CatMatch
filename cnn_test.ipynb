# %%
from PIL import Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from catmatch.cnn.preprocessing.image_embeddings import get_image_embeddings
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# c:\Users\ugioh\code\catmatch\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\ugioh\code\catmatch\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
image1 = Image.open("./.data/Abyssinian/Abyssinian-38901579_217.jpg").convert("RGB")
plt.imshow(image1)

# %%
image2 = Image.open("./.data/Abyssinian/Abyssinian-16734355_246.jpg").convert("RGB")
plt.imshow(image2)

# %%
get_image_embeddings(image1)
# Out:
# c:\Users\ugioh\code\catmatch\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\ugioh\code\catmatch\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# tensor([[-0.1768,  0.2302, -0.1961,  ..., -0.1900,  0.1599, -0.0556]])

# %%
cosine_similarity(get_image_embeddings(image1), get_image_embeddings(image2))
# Out:
# c:\Users\ugioh\code\catmatch\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\ugioh\code\catmatch\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# array([[0.6222322]], dtype=float32)

# %% [markdown]
# High number - great!

# %%
image_ab = Image.open("./.data/Abyssinian/Abyssinian-38901579_217.jpg").convert("RGB")
plt.imshow(image_ab)

# %%
image_bengal = Image.open("./.data/Egyptian Mau/Egyptian_Mau--12.jpg").convert("RGB")
plt.imshow(image_bengal)

# %%
cosine_similarity(get_image_embeddings(image_ab), get_image_embeddings(image_bengal))
# Out:
# c:\Users\ugioh\code\catmatch\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\ugioh\code\catmatch\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# array([[0.10035199]], dtype=float32)
